# %%
import pandas as pd

courses_df = pd.read_csv(r'D:\python\evertrial\courses_data.csv')
courses_df
# Out:
#                                       과정  \
# 0                                   전공심화
# 1                                   전공심화
# 2                                   전공심화
# 3                                   정규일반
# 4                                   정규일반
# 5                                   정규일반
# 6                                   정규일반
# 7                                   정규일반
# 8                                   정규일반
# 9                                   정규일반
# 10                                  정규일반
# 11                                  정규일반
# 12                                  정규일반
# 13                                  정규일반
# 14                                  정규일반
# 15                                  정규일반
# 16                                  정규일반
# 17                                  정규일반
# 18                                  정규일반
# 19                                  정규일반
# 20                                  정규일반
# 21                                  정규일반
# ...
