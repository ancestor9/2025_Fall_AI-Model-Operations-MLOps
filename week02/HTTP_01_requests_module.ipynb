# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/2025_Fall_AI-Model-Operations-MLOps/blob/main/week02/HTTP_01_requests_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **API Request**
# <img src='https://media.geeksforgeeks.org/wp-content/uploads/20230216170349/What-is-an-API.png'>
#
# >##### API(application programming interface 애플리케이션 프로그래밍 인터페이스, 응용 프로그램 프로그래밍 인터페이스)는 컴퓨터나 컴퓨터 프로그램 사이의 연결이다. 일종의 소프트웨어 인터페이스이며 다른 종류의 소프트웨어에 서비스를 제공한다.(wiki)
# >> - 1. 서로 다른 소프트웨어시스템간의 통신 (print('Hello'), document.write('Hello'), Scikit-learn의 Estimators API)
# >>> - https://scikit-learn.org/stable/modules/classes.html
# >> - 2. 인터넷 환경에서 특정 유형의 서버에 상주하며 일종의 데이터베이스를 조작

# %% [markdown]
# - https://requests.readthedocs.io/en/latest/

# %%
import requests
r = requests.get('https://api.github.com/events')
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Date': 'Thu, 04 Sep 2025 04:56:58 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"b5344e4a99bd3594420f11963221a530f4bb5415f9e8686ada62ffb84b290cd9"', 'Last-Modified': 'Thu, 04 Sep 2025 04:51:57 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=9>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1756965417', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'A168:86BD0:3AC01CF:3BE8E12:68B91C19'}

# %% [markdown]
# >>> - https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses

# %%
r.headers['content-type']
# 응답 객체 r에서 Content Type 헤더의 값으로 응답으로 전송되는 리소스의 미디어 유형
# 예를 들어, 응답 본문이 JSON 형식 (application/json)이거나 HTML 형식 (text/html) 등
# Out:
# 'application/json; charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '[{"id":"54227957742","type":"PushEvent","actor":{"id":80447042,"login":"ze0ns","display_login":"ze0ns","gravatar_id":"","url":"https://api.github.com/users/ze0ns","avatar_url":"https://avatars.githubusercontent.com/u/80447042?"},"repo":{"id":1050153499,"name":"ze0ns/Counter","url":"https://api.github.com/repos/ze0ns/Counter"},"payload":{"repository_id":1050153499,"push_id":26573888441,"size":1,"distinct_size":1,"ref":"refs/heads/sprint_03","head":"d9d601f30375a6aec926dd6037a19d8cca87a461","before":"bb8ed1c64925094b443bf65454f59087bc0558b3","commits":[{"sha":"d9d601f30375a6aec926dd6037a19d8cca87a461","author":{"email":"oao@i-cio.ru","name":"zeons"},"message":"Решено сложное задание","distinct":true,"url":"https://api.github.com/repos/ze0ns/Counter/commits/d9d601f30375a6aec926dd6037a19d8cca87a461"}]},"public":true,"created_at":"2025-09-04T04:51:57Z"},{"id":"54227957775","type":"CreateEvent","actor":{"id":203760335,"login":"Hemalatha-17-nov","display_login":"Hemalatha-17-nov","gravatar_id":"","url":"https://api.github.com/users/Hemalatha-17-nov","avatar_url":"https://avatars.githubusercontent.com/u/203760335?"},"repo":{"id":1050193032,"name":"Hemalatha-17-nov/css-module5-project","url":"https://api.github.com/repos/Hemalatha-17-nov/css-module5-project"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2025-09-04T04:51:57Z"},{"id":"54227957745","type":"CreateEvent","actor":{"id":29139614,"login":"renovate[bot]","display_login":"renovate","gravatar_id":"","url":"https://api.github.com/users/renovate[bot]","avatar_url":"https://avatars.githubusercontent.com/u/29139614?"},"repo":{"id":689403814,"name":"noah-guillory/remix-auth-whoop","url":"https://api.github.com/repos/noah-guillory/remix-auth-whoop"},"payload":{"ref":"renovate/actions-setup-node-5.x","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2025-09-04T04:51:57Z"},{"id":"54227957736","type":"PullRequestReviewCommentEvent","actor":{"id":85498834,"login":"ggiguash","display_login":"ggiguash","gravatar_id":"","url":"https://api.github.com/users/ggiguash","avatar_url":"https://avatars.githubusercontent.com/u/85498834?"},"repo":{"id":361784175,"name":"openshift/microshift","url":"https://api.github.com/repos/openshift/microshift"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/openshift/microshift/pulls/comments/2320821596","pull_request_review_id":3183409693,"id":2320821596,"node_id":"PRRC_kwDOFZBjb86KVO1c","diff_hunk":"@@ -17,7 +17,8 @@ RUN --mount=type=secret,id=pullsecret,dst=/run/secrets/pull-secret.json \\\\\\n         sha=\\"$(echo \\"${img}\\" | sha256sum | awk \'{print $1}\')\\" ; \\\\\\n         skopeo copy --all --preserve-digests \\\\\\n             --authfile /run/secrets/pull-secret.json \\\\\\n-            \\"docker://${img}\\" \\"dir:$IMAGE_STORAGE_DIR/${sha}\\" ; \\\\\\n+            \\"docker://${img}\\" \\"dir:$IMAGE_STORAGE_DIR/${sha}\\" \\\\\\n+            || { echo \'!!! skopeo copy failed\' ; exit 1; } ; \\\\","path":"docs/config/Containerfile.bootc-embedded-rhel9","commit_id":"ca912b8dd8cb987acf0a2ec149d4573d378e110c","original_commit_id":"ca912b8dd8cb987acf0a2ec149d4573d378e110c","user":{"login":"ggiguash","id":85498834,"node_id":"MDQ6VXNlcjg1NDk4ODM0","avatar_url":"https://avatars.githubusercontent.com/u/85498834?v=4","gravatar_id":"","url":"https://api.github.com/users/ggiguash","html_url":"https://github.com/ggiguash","followers_url":"https://api.github.com/users/ggiguash/followers","following_url":"https://api.github.com/users/ggiguash/following{/other_user}","gists_url":"https://api.github.com/users/ggiguash/gists{/gist_id}","starred_url":"https://api.github.com/users/ggiguash/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ggiguash/subscriptions","organizations_url":"https://api.github.com/users/ggiguash/orgs","repos_url":"https://api.github.com/ ...

# %%
data = r.json()
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 30

# %%
data[0]
# Out:
# {'id': '54227957742',
#  'type': 'PushEvent',
#  'actor': {'id': 80447042,
#   'login': 'ze0ns',
#   'display_login': 'ze0ns',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ze0ns',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/80447042?'},
#  'repo': {'id': 1050153499,
#   'name': 'ze0ns/Counter',
#   'url': 'https://api.github.com/repos/ze0ns/Counter'},
#  'payload': {'repository_id': 1050153499,
#   'push_id': 26573888441,
#   'size': 1,
#   'distinct_size': 1,
#   'ref': 'refs/heads/sprint_03',
#   'head': 'd9d601f30375a6aec926dd6037a19d8cca87a461',
#   'before': 'bb8ed1c64925094b443bf65454f59087bc0558b3',
#   'commits': [{'sha': 'd9d601f30375a6aec926dd6037a19d8cca87a461',
#     'author': {'email': 'oao@i-cio.ru', 'name': 'zeons'},
#     'message': 'Решено сложное задание',
#     'distinct': True,
#     'url': 'https://api.github.com/repos/ze0ns/Counter/commits/d9d601f30375a6aec926dd6037a19d8cca87a461'}]},
#  'public': True,
#  'created_at': '2025-09-04T04:51:57Z'}

# %%
type(data)
# Out:
# list

# %%
data[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at'])

# %%
import pandas as pd
df = pd.DataFrame(data)  # list to dataframe
df
# Out:
#              id                           type  \
# 0   54227957742                      PushEvent
# 1   54227957775                    CreateEvent
# 2   54227957745                    CreateEvent
# 3   54227957736  PullRequestReviewCommentEvent
# 4   54227957686                      PushEvent
# 5   54227957723              IssueCommentEvent
# 6   54227957706                     WatchEvent
# 7   54227957695                    DeleteEvent
# 8   54227957683                    DeleteEvent
# 9   54227957676                      PushEvent
# 10  54227957666                      PushEvent
# 11  54227957654                      PushEvent
# 12  54227957665                    CreateEvent
# 13  54227957672         PullRequestReviewEvent
# 14  54227957673                    DeleteEvent
# 15  54227957642                      PushEvent
# 16  54227957658                    DeleteEvent
# 17  54227957656                    DeleteEvent
# 18  54227957638                      PushEvent
# 19  54227957639                    DeleteEvent
# 20  54227957619                      PushEvent
# 21  54227957617                      PushEvent
# 22  54227957627                    DeleteEvent
# 23  54227957607                      PushEvent
# 24  54227957592                      PushEvent
# 25  54227957608                    CreateEvent
# 26  54227957598                      PushEvent
# 27  54227957596                    DeleteEvent
# 28  54227957569                      PushEvent
# 29  54227957578              IssueCommentEvent
#
#                                                 actor  \
# 0   {'id': 80447042, 'login': 'ze0ns', 'display_lo...
# 1   {'id': 203760335, 'login': 'Hemalatha-17-nov',...
# 2   {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 3   {'id': 85498834, 'login': 'ggiguash', 'display...
# 4   {'id': 41898282, 'login': 'github-actions[bot]...
# 5   {'id': 37597874, 'login': 'RatkoVasic-NOAA', '...
# 6   {'id': 228357151, 'login': 'muksasm', 'display...
# 7   {'id': 116911743, 'login': 'lowcodebox', 'disp...
# 8   {'id': 116911743, 'login': 'lowcodebox', 'disp...
# 9   {'id': 18514139, 'login': 'ozw4', 'display_log...
# 10  {'id': 41898282, 'login': 'github-actions[bot]...
# 11  {'id': 37974674, 'login': 'alijayanet', 'displ...
# 12  {'id': 230295485, 'login': 'giorgiotebn03-art'...
# 13  {'id': 85498834, 'login': 'ggiguash', 'display...
# 14  {'id': 116911743, 'login': 'lowcodebox', 'disp...
# 15  {'id': 41898282, 'login': 'github-actions[bot]...
# 16  {'id': 116911743, 'login': 'lowcodebox', 'disp...
# 17  {'id': 116911743, 'login': 'lowcodebox', 'disp...
# 18  {'id': 209506819, 'login': 'Ameena-Begum-tech'...
# 19  {'id': 116911743, 'login': 'lowcodebox', 'disp...
# 20  {'id': 96137983, 'login': 'sleyter93', 'displa...
# 21  {'id': 41898282, 'login': 'github-actions[bot]...
# 22  {'id': 116911743, 'login': 'lowcodebox', 'disp...
# 23  {'id': 128366806, 'login': 'azizt91', 'display...
# 24  {'id': 58712803, 'login': 'not-night-but', 'di...
# 25  {'id': 174191686, 'login': 'Joshithach18', 'di...
# 26  {'id': 67166177, 'login': 'husniabad', 'displa...
# 27  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 28  {'id': 229253670, 'login': 'AlsoNotTze1', 'dis...
# 29  {'id': 35613825, 'login': 'vercel[bot]', 'disp...
#
#                                                  repo  \
# 0   {'id': 1050153499, 'name': 'ze0ns/Counter', 'u...
# 1   {'id': 1050193032, 'name': 'Hemalatha-17-nov/c...
# 2   {'id': 689403814, 'name': 'noah-guillory/remix...
# 3   {'id': 361784175, 'name': 'openshift/microshif...
# 4   {'id': 660104479, 'name': 'RohitPrajapat00/GIt...
# 5   {'id': 215322081, 'name': 'ufs-community/ufs-w...
# 6   {'id': 808144141, 'name': 'DigitalPlatDev/Free...
# 7   {'id': 793947316, 'name': 'lowcodebox/lib', 'u...
# 8   {'id': 793947316, 'name': 'lowcodebox/lib', 'u...
# 9   {'id': 1028784217, 'name': 'ozw4/seisviewer2d'...
# 10  {'id': 1001739366, 'name': 'h4t3p1ckl3s/h4t3p1...
# 11  {'id': 1032460799, 'name': 'alijayanet/gembok-...
# 12  {'id': 1050193031, 'name': 'giorgiotebn03-art/...
# 13  {'id': 361784175, 'name': 'openshift/microshif...
# 14  {'id': 793947316, 'name': 'lowcodebox/lib', 'u...
# 15  {'id': 1015249915, 'name': 'beeharry09/skyline...
# 16  {'id': 793947316, 'name': 'lowcodebox/lib', 'u...
# 17  {'id': 793947316, 'name': 'lowcodebox/lib', 'u...
# 18  {'id': 1044401282, 'name': 'Ameena-Begum-tech/...
# 19  {'id': 793947316, 'name': 'lowcodebox/lib', 'u...
# 20  {'id': 803285289, 'name': 'RootstockCollective...
# 21  {'id': 964590992, 'name': 'uditsingh21/btc_tac...
# 22  {'id': 793947316, 'name': 'lowcodebox/lib', 'u...
# 23  {'id': 1044298129, 'name': 'azizt91/spreadshee...
# 24  {'id': 198484780, 'name': 'beekeeper-studio/be...
# 25  {'id': 1050192243, 'name': 'Joshithach18/22FE1...
# 26  {'id': 1046550394, 'name': 'husniabad/NoteBook...
# 27  {'id': 1009792324, 'name': 'lootup-team/nestjs...
# 28  {'id': 1046663351, 'name': 'AlsoNotTze1/anatom...
# 29  {'id': 1038371631, 'name': 'guerrinharj/isca',...
#
#                                               payload  public  \
# 0   {'repository_id': 1050153499, 'push_id': 26573...    True
# 1   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 2   {'ref': 'renovate/actions-setup-node-5.x', 're...    True
# 3   {'action': 'created', 'comment': {'url': 'http...    True
# 4   {'repository_id': 660104479, 'push_id': 265738...    True
# 5   {'action': 'created', 'issue': {'url': 'https:...    True
# 6                               {'action': 'started'}    True
# 7   {'ref': 'wpr-4980/xsvckey-multidomain', 'ref_t...    True
# 8   {'ref': 'feature/wpr-4621-add-timeout', 'ref_t...    True
# 9   {'repository_id': 1028784217, 'push_id': 26573...    True
# 10  {'repository_id': 1001739366, 'push_id': 26573...    True
# 11  {'repository_id': 1032460799, 'push_id': 26573...    True
# 12  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 13  {'action': 'created', 'review': {'id': 3183409...    True
# 14  {'ref': 'feature/wpr-4728-spaces-ru-lang', 're...    True
# 15  {'repository_id': 1015249915, 'push_id': 26573...    True
# 16  {'ref': 'feature/put-object', 'ref_type': 'bra...    True
# 17  {'ref': 'feature/vfs-presigned-url', 'ref_type...    True
# 18  {'repository_id': 1044401282, 'push_id': 26573...    True
# 19  {'ref': 'wpr-4980/for-old-ver', 'ref_type': 'b...    True
# 20  {'repository_id': 803285289, 'push_id': 265738...    True
# 21  {'repository_id': 964590992, 'push_id': 265738...    True
# 22  {'ref': 'feature/wpr-4621-add-timeout-v2', 're...    True
# 23  {'repository_id': 1044298129, 'push_id': 26573...    True
# 24  {'repository_id': 198484780, 'push_id': 265738...    True
# 25  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 26  {'repository_id': 1046550394, 'push_id': 26573...    True
# 27  {'ref': 'dependabot/npm_and_yarn/typescript-es...    True
# 28  {'repository_id': 1046663351, 'push_id': 26573...    True
# 29  {'action': 'created', 'issue': {'url': 'https:...    True
#
#               created_at                                                org
# 0   2025-09-04T04:51:57Z                                                NaN
# 1   2025-09-04T04:51:57Z                                                NaN
# 2   2025-09-04T04:51:57Z                                                NaN
# 3   2025-09-04T04:51:56Z  {'id': 792337, 'login': 'openshift', 'gravatar...
# 4   2025-09-04T04:51:57Z                                                NaN
# 5   2025-09-04T04:51:57Z  {'id': 49994907, 'login': 'ufs-community', 'gr...
# 6   2025-09-04T04:51:57Z  {'id': 126394654, 'login': 'DigitalPlatDev', '...
# 7   2025-09-04T04:51:57Z                                                NaN
# 8   2025-09-04T04:51:57Z                                                NaN
# 9   2025-09-04T04:51:57Z                                                NaN
# 10  2025-09-04T04:51:57Z                                                NaN
# 11  2025-09-04T04:51:57Z                                                NaN
# 12  2025-09-04T04:51:57Z                                                NaN
# 13  2025-09-04T04:51:57Z  {'id': 792337, 'login': 'openshift', 'gravatar...
# 14  2025-09-04T04:51:57Z                                                NaN
# 15  2025-09-04T04:51:57Z                                                NaN
# 16  2025-09-04T04:51:57Z                                                NaN
# 17  2025-09-04T04:51:57Z                                                NaN
# 18  2025-09-04T04:51:57Z                                                NaN
# 19  2025-09-04T04:51:57Z                                                NaN
# 20  2025-09-04T04:51:57Z  {'id': 179749524, 'login': 'RootstockCollectiv...
# 21  2025-09-04T04:51:57Z                                                NaN
# 22  2025-09-04T04:51:57Z                                                NaN
# 23  2025-09-04T04:51:57Z                                                NaN
# 24  2025-09-04T04:51:57Z  {'id': 53234021, 'login': 'beekeeper-studio', ...
# 25  2025-09-04T04:51:57Z                                                NaN
# 26  2025-09-04T04:51:57Z                                                NaN
# 27  2025-09-04T04:51:57Z  {'id': 210711011, 'login': 'lootup-team', 'gra...
# 28  2025-09-04T04:51:57Z                                                NaN
# 29  2025-09-04T04:51:57Z                                                NaN

# %%
for content in df['actor'][:10]:
    print(content)
# Out:
# {'id': 80447042, 'login': 'ze0ns', 'display_login': 'ze0ns', 'gravatar_id': '', 'url': 'https://api.github.com/users/ze0ns', 'avatar_url': 'https://avatars.githubusercontent.com/u/80447042?'}
# {'id': 203760335, 'login': 'Hemalatha-17-nov', 'display_login': 'Hemalatha-17-nov', 'gravatar_id': '', 'url': 'https://api.github.com/users/Hemalatha-17-nov', 'avatar_url': 'https://avatars.githubusercontent.com/u/203760335?'}
# {'id': 29139614, 'login': 'renovate[bot]', 'display_login': 'renovate', 'gravatar_id': '', 'url': 'https://api.github.com/users/renovate[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'}
# {'id': 85498834, 'login': 'ggiguash', 'display_login': 'ggiguash', 'gravatar_id': '', 'url': 'https://api.github.com/users/ggiguash', 'avatar_url': 'https://avatars.githubusercontent.com/u/85498834?'}
# {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}
# {'id': 37597874, 'login': 'RatkoVasic-NOAA', 'display_login': 'RatkoVasic-NOAA', 'gravatar_id': '', 'url': 'https://api.github.com/users/RatkoVasic-NOAA', 'avatar_url': 'https://avatars.githubusercontent.com/u/37597874?'}
# {'id': 228357151, 'login': 'muksasm', 'display_login': 'muksasm', 'gravatar_id': '', 'url': 'https://api.github.com/users/muksasm', 'avatar_url': 'https://avatars.githubusercontent.com/u/228357151?'}
# {'id': 116911743, 'login': 'lowcodebox', 'display_login': 'lowcodebox', 'gravatar_id': '', 'url': 'https://api.github.com/users/lowcodebox', 'avatar_url': 'https://avatars.githubusercontent.com/u/116911743?'}
# {'id': 116911743, 'login': 'lowcodebox', 'display_login': 'lowcodebox', 'gravatar_id': '', 'url': 'https://api.github.com/users/lowcodebox', 'avatar_url': 'https://avatars.githubusercontent.com/u/116911743?'}
# {'id': 18514139, 'login': 'ozw4', 'display_login': 'ozw4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ozw4', 'avatar_url': 'https://avatars.githubusercontent.com/u/18514139?'}
